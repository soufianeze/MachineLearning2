# %% [markdown]
# <a href="https://colab.research.google.com/github/soufianeze/MachineLearning2/blob/main/Kayak_DEMO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import requests
from geopy.extra.rate_limiter import RateLimiter
import json

# %%
#Creating a dataframe with address of locations we want to reterive
locat = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]
df = pd.DataFrame({'add': locat})

# %%
#Creating an instance of Nominatim Class
geolocator = Nominatim(user_agent="my_request")
 
#applying the rate limiter wrapper
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
 
#Applying the method to pandas DataFrame
df['location'] = df['add'].apply(geocode)
df['latitude'] = df['location'].apply(lambda x: x.latitude if x else None)
df['longitude'] = df['location'].apply(lambda x: x.longitude if x else None)
 
df
# Out:
#                              add  \
# 0              Mont Saint Michel
# 1                        St Malo
# 2                         Bayeux
# 3                       Le Havre
# 4                          Rouen
# 5                          Paris
# 6                         Amiens
# 7                          Lille
# 8                     Strasbourg
# 9   Chateau du Haut Koenigsbourg
# 10                        Colmar
# 11                     Eguisheim
# 12                      Besancon
# 13                         Dijon
# 14                        Annecy
# 15                      Grenoble
# 16                          Lyon
# 17              Gorges du Verdon
# 18            Bormes les Mimosas
# 19                        Cassis
# 20                     Marseille
# 21               Aix en Provence
# 22                       Avignon
# 23                          Uzes
# 24                         Nimes
# 25                 Aigues Mortes
# 26      Saintes Maries de la mer
# ...

# %%
df.head(5)
# Out:
#                  add                                           location  \
# 0  Mont Saint Michel  (Mont Saint-Michel, Avancée des Bombardes, Le ...
# 1            St Malo  (Saint-Malo, Ille-et-Vilaine, Bretagne, France...
# 2             Bayeux  (Bayeux, Calvados, Normandie, France métropoli...
# 3           Le Havre  (Le Havre, Seine-Maritime, Normandie, France m...
# 4              Rouen  (Rouen, Seine-Maritime, Normandie, France métr...
#
#     latitude  longitude
# 0  48.635954  -1.511460
# 1  48.649518  -2.026041
# 2  49.276462  -0.702474
# 3  49.493898   0.107973
# 4  49.440459   1.093966

# %%
df1 = df.drop(['location'], axis=1)

# %%
df_coord_city =  df1

# %%
df_coord_city.to_csv(path_or_buf= 'df_coord_city.csv')

# %%
df_coord_city = pd.read_csv('df_coord_city.csv',index_col=[0])
df_coord_city
# Out:
#                              add   latitude  longitude
# 0              Mont Saint Michel  48.635954  -1.511460
# 1                        St Malo  48.649518  -2.026041
# 2                         Bayeux  49.276462  -0.702474
# 3                       Le Havre  49.493898   0.107973
# 4                          Rouen  49.440459   1.093966
# 5                          Paris  48.858890   2.320041
# 6                         Amiens  49.894171   2.295695
# 7                          Lille  50.636565   3.063528
# 8                     Strasbourg  48.584614   7.750713
# 9   Chateau du Haut Koenigsbourg  48.249490   7.344296
# 10                        Colmar  48.077752   7.357964
# 11                     Eguisheim  48.044797   7.307962
# 12                      Besancon  47.238022   6.024362
# 13                         Dijon  47.321581   5.041470
# 14                        Annecy  45.899235   6.128885
# 15                      Grenoble  45.187560   5.735782
# ...

# %%
apikey = "2d2d38d27bf70441956404225db6021f"

# %%
d={}
for i in range(8):
  d["day"+str(i)]=[]
    
for i in range(len(df_coord_city)):
  latitude = df_coord_city.loc[i,'latitude']
  longitude = df_coord_city.loc[i,'longitude']
  url=f"https://api.openweathermap.org/data/2.5/onecall?lat={latitude}&lon={longitude}&appid={apikey}&exclude=minutely"
  r=requests.get(url)
    
  for i in range(8):
    d["day"+str(i)].append(r.json()['daily'][i])

with open("meteo.json", 'w') as m_json:
    m_json.write(json.dumps(d))
        
meteo=pd.read_json('meteo.json')
meteo.head(1)
# Out:
#                                                 day0  \
# 0  {'dt': 1658750400, 'sunrise': 1658723446, 'sun...
#
#                                                 day1  \
# 0  {'dt': 1658836800, 'sunrise': 1658809921, 'sun...
#
#                                                 day2  \
# 0  {'dt': 1658923200, 'sunrise': 1658896397, 'sun...
#
#                                                 day3  \
# 0  {'dt': 1659009600, 'sunrise': 1658982874, 'sun...
#
#                                                 day4  \
# 0  {'dt': 1659096000, 'sunrise': 1659069352, 'sun...
#
#                                                 day5  \
# 0  {'dt': 1659182400, 'sunrise': 1659155830, 'sun...
#
#                                                 day6  \
# 0  {'dt': 1659268800, 'sunrise': 1659242310, 'sun...
#
#                                                 day7
# 0  {'dt': 1659355200, 'sunrise': 1659328789, 'sun...

# %%
def rempli_jour(jour,j):
    
    for i in range(jour.shape[0]):
        jour.loc[i,'date'] = meteo.iloc[i,j]['dt']
        jour.loc[i,'Tmin'] = meteo.iloc[i,j]['temp']['min']-273.15
        jour.loc[i,'Tmax'] = meteo.iloc[i,j]['temp']['max']-273.15
        jour.loc[i,'Humidity'] = meteo.iloc[i,j]['humidity']
        jour.loc[i,'Weather'] = meteo.iloc[i,j]['weather'][0]['main'] + " (" + meteo.iloc[i,j]['weather'][0]['description'] + ')'
        jour.loc[i,'clouds'] = meteo.iloc[i,j]['clouds']
        jour.loc[i,'WeatherCode'] = meteo.iloc[i,j]['weather'][0]['id']
        jour.loc[i,'icone'] = 'http://openweathermap.org/img/wn/'+meteo.iloc[i,j]['weather'][0]['icon']+'.png'
    jour.date = pd.to_datetime(jour.date, unit = 's')
    return None

locs = locals()
for i in range(8):
    locs['jour_'+str(i)] = df_coord_city.copy()
    rempli_jour( locs['jour_'+str(i)] ,i)
    
jour_1.head(1)
# Out:
#                  add   latitude  longitude                date   Tmin   Tmax  \
# 0  Mont Saint Michel  48.635954   -1.51146 2022-07-26 12:00:00  14.12  21.92
#
#    Humidity                   Weather  clouds  WeatherCode  \
# 0      47.0  Clouds (overcast clouds)   100.0        804.0
#
#                                       icone
# 0  http://openweathermap.org/img/wn/04d.png

# %%
 url=f"https://api.openweathermap.org/data/2.5/onecall?lat={lat1}&lon={lon1}&appid={apikey}&exclude=minutely"
r=requests.get(url)

# %%
apikey = "2d2d38d27bf70441956404225db6021f" 

df = pd.DataFrame(columns=['location','latitude', 'longitude', 'day', 'weather'])

for i in range(len(df_coord_city)): 
  url=f"https://api.openweathermap.org/data/2.5/onecall?lat={latitude}&lon={longitude}&appid={apikey}&exclude=minutely"
  rson=r.json()
  d={}
  for n in range(7):
    loc = df_coord_city['add'][i]
    latitude = df_coord_city['latitude'][i]
    longitude = df_coord_city['longitude'][i]
    day = n+1
    weather =  rson['daily'][n]['weather'][0]['description']
    d = {'location': loc,'latitude': latitude,'longitude': longitude,'day': day, 'weather': weather}
    df = pd.concat([df, pd.DataFrame(d, index=[0])], ignore_index=True)

# %%
df.head(10)
# Out:
#             location   latitude  longitude day           weather
# 0  Mont Saint Michel  48.635954  -1.511460   1        light rain
# 1  Mont Saint Michel  48.635954  -1.511460   2        light rain
# 2  Mont Saint Michel  48.635954  -1.511460   3  scattered clouds
# 3  Mont Saint Michel  48.635954  -1.511460   4        light rain
# 4  Mont Saint Michel  48.635954  -1.511460   5   overcast clouds
# 5  Mont Saint Michel  48.635954  -1.511460   6        light rain
# 6  Mont Saint Michel  48.635954  -1.511460   7        light rain
# 7            St Malo  48.649518  -2.026041   1        light rain
# 8            St Malo  48.649518  -2.026041   2        light rain
# 9            St Malo  48.649518  -2.026041   3  scattered clouds
